# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("skincare_products_clean.csv")
print("✅ Dataset loaded successfully!")
# Out:
# ✅ Dataset loaded successfully!

# %%
print("🔍 First 5 rows of the dataset:")
print(df.head())
# Out:
# 🔍 First 5 rows of the dataset:
#                                         product_name  \
# 0  The Ordinary Natural Moisturising Factors + HA...
# 1      CeraVe Facial Moisturising Lotion SPF 25 52ml
# 2  The Ordinary Hyaluronic Acid 2% + B5 Hydration...
# 3          AMELIORATE Transforming Body Lotion 200ml
# 4                     CeraVe Moisturising Cream 454g
#
#                                          product_url product_type  \
# 0  https://www.lookfantastic.com/the-ordinary-nat...  Moisturiser
# 1  https://www.lookfantastic.com/cerave-facial-mo...  Moisturiser
# 2  https://www.lookfantastic.com/the-ordinary-hya...  Moisturiser
# 3  https://www.lookfantastic.com/ameliorate-trans...  Moisturiser
# 4  https://www.lookfantastic.com/cerave-moisturis...  Moisturiser
#
#                                        clean_ingreds   price
# 0  ['capric triglyceride', 'cetyl alcohol', 'prop...   £5.20
# 1  ['homosalate', 'glycerin', 'octocrylene', 'eth...  £13.00
# ...

# %%
df.tail()
# Out:
#                                            product_name  \
# 1133  Elemis Life Elixirs Embrace Bath and Shower El...
# 1134     Love Boo Splendidly Soothing Bath Soak (250ml)
# 1135  Elemis Life Elixirs Fortitude Bath and Shower ...
# 1136  Connock London Kukui Oil Soothing Bath & Showe...
# 1137           Weleda Baby Calendula Cream Bath (200ml)
#
#                                             product_url product_type  \
# 1133  https://www.lookfantastic.com/elemis-life-elix...     Bath Oil
# 1134  https://www.lookfantastic.com/love-boo-splendi...     Bath Oil
# 1135  https://www.lookfantastic.com/elemis-life-elix...     Bath Oil
# 1136  https://www.lookfantastic.com/connock-london-k...     Bath Oil
# 1137  https://www.lookfantastic.com/weleda-baby-cale...     Bath Oil
#
#                                           clean_ingreds   price
# 1133  ['prunus amygdalus dulcis', 'tipa-laureth sulf...  £55.00
# 1134  ['sodium lauroyl', 'sodium cocoamphoacetate', ...  £10.99
# ...

# %%
print("📊 Shape of the dataset (rows, columns):")
print(df.shape)
# Out:
# 📊 Shape of the dataset (rows, columns):
# (1138, 5)

# %%
print("🧾 Data Types and Null Info:")
print(df.info())
# Out:
# 🧾 Data Types and Null Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1138 entries, 0 to 1137
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   1138 non-null   object
#  1   product_url    1138 non-null   object
#  2   product_type   1138 non-null   object
#  3   clean_ingreds  1138 non-null   object
#  4   price          1138 non-null   object
# dtypes: object(5)
# memory usage: 44.6+ KB
# None

# %%
print("🧹 Missing Values in Each Column:")
print(df.isnull().sum())
# Out:
# 🧹 Missing Values in Each Column:
# product_name     0
# product_url      0
# product_type     0
# clean_ingreds    0
# price            0
# dtype: int64

# %%
print("📈 Statistical Summary:")
print(df.describe())
# Out:
# 📈 Statistical Summary:
#                                              product_name  \
# count                                                1138
# unique                                               1138
# top     The Ordinary Natural Moisturising Factors + HA...
# freq                                                    1
#
#                                               product_url product_type  \
# count                                                1138         1138
# unique                                               1126           14
# top     https://www.lookfantastic.com/lancome-advanced...         Mask
# freq                                                    4          124
#
#               clean_ingreds   price
# count                  1138    1138
# unique                 1071     290
# top     ['sodium chloride']  £22.00
# freq                      5      33

# %%
print("📈 Statistical Summary:")
print(df.describe())
# Out:
# 📈 Statistical Summary:
#                                              product_name  \
# count                                                1138
# unique                                               1138
# top     The Ordinary Natural Moisturising Factors + HA...
# freq                                                    1
#
#                                               product_url product_type  \
# count                                                1138         1138
# unique                                               1126           14
# top     https://www.lookfantastic.com/lancome-advanced...         Mask
# freq                                                    4          124
#
#               clean_ingreds   price
# count                  1138    1138
# unique                 1071     290
# top     ['sodium chloride']  £22.00
# freq                      5      33

# %%
print("🏷️ Top 10 Brands by Product Count:")
print(df['product_name'].value_counts().head(10))
# Out:
# 🏷️ Top 10 Brands by Product Count:
# product_name
# The Ordinary Natural Moisturising Factors + HA 30ml            1
# Clinique Redness Solutions Soothing Cleanser 150ml             1
# PIXI Glow Tonic Cleansing Gel 135ml                            1
# Elemis Balancing Lime Blossom Cleanser 200ml                   1
# Murad Age Reform Aha/Bha Exfoliating Cleanser (200ml)          1
# La Roche-Posay Effaclar Micellar Water 200ml                   1
# Bulldog Original 2-in-1 Beard Shampoo and Conditioner 200ml    1
# REN Evercalm™ Gentle Cleansing Milk 150ml                      1
# L'Oréal Paris Fine Flowers Cleansing Wash 150ml                1
# DHC Face Wash Powder (50g)                                     1
# Name: count, dtype: int64

# %%
print("🌟 Top 10 Highest Rated Products:")
top_rated = df.sort_values(by='product_type', ascending=False).head(10)
print(top_rated[[ 'product_name', 'product_type', 'price']])
# Out:
# 🌟 Top 10 Highest Rated Products:
#                                           product_name product_type   price
# 826                 Clinique Clarifying Lotion 2 200ml        Toner  £18.00
# 834                             PIXI Milky Tonic 100ml        Toner  £10.00
# 836  Estée Lauder Perfectly Clean Multi-Action Toni...        Toner  £21.60
# 837                 Clinique Clarifying Lotion 3 200ml        Toner  £18.00
# 838                 Clinique Clarifying Lotion 3 400ml        Toner  £28.00
# 839  Estée Lauder Micro Essence Skin Activating Tre...        Toner  £79.00
# 841                Lancôme Tonique Confort Toner 400ml        Toner  £37.35
# 842                      OSKIA Floral Water Toner 30ml        Toner  £14.00
# 843  First Aid Beauty Ultra Repair Wild Oat Soothin...        Toner  £19.00
# 844  Pai Lotus and Orange Blossom BioAffinity Toner...        Toner  £30.00

# %%
print("📊 Bar Plot: Top 10 Brands by Product Count")
plt.figure(figsize=(10, 5))
df['product_name'].value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Brands by Product Count')
plt.xlabel('product_name')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# 📊 Bar Plot: Top 10 Brands by Product Count

# %%
print("💵 Histogram: Product Price Distribution")
plt.figure(figsize=(8, 5))
sns.histplot(df['price'], bins=30, kde=True, color='lightgreen')
plt.title('Product Price Distribution')
plt.xlabel('Price')
plt.ylabel('Number of Products')
plt.tight_layout()
plt.show()
# Out:
# 💵 Histogram: Product Price Distribution

# %%
print("🧾 Column Names in Dataset:")
print(df.columns.tolist())
# Out:
# 🧾 Column Names in Dataset:
# ['product_name', 'product_url', 'product_type', 'clean_ingreds', 'price']

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df = df.dropna(subset=['price'])
print("✅ Price column cleaned. Rows with missing prices dropped.")
# Out:
# ✅ Price column cleaned. Rows with missing prices dropped.
